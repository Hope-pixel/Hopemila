# %% [markdown]
# <a href="https://colab.research.google.com/github/Hope-pixel/Hopemila/blob/main/Copy_of_DTS_WEEK_3_Python_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT 1. Create a list of 5 student scores

# %%
scores = [80,30,50,45,75]
print(scores)
# Out:
# [80, 30, 50, 45, 75]

# %% [markdown]
# # ASSIGNMENT 2. Compute the average score

# %%
total = 0
for score in scores:
    total = total + score

average = total / len(scores)
print("Average score:", average)
# Out:
# Average score: 56.0

# %% [markdown]
# # ASSIGNMENT 3. Find the highest score

# %%
highest = scores[0]
for score in scores:
    if score > highest:
        highest = score

print("Highest score:", highest)
# Out:
# Highest score: 80

# %% [markdown]
# # ASSIGNMENT 4. Create a dictionary with 5 students and scores

# %%
scores_set = {80,30,50,45,75}
print(scores_set)
# Out:
# {80, 50, 75, 45, 30}

# %% [markdown]
# # ASSIGNMENT 5. Find the highest scoring student

# %%
highest_id = None
highest_score = 0

for student_id in students:
    score = students[student_id]

    if score > highest_score:
        highest_score = score
        highest_id = student_id

print("Highest scoring student:", highest_id)
print("Score:", highest_score)
# Out:
# Highest scoring student: S004
# Score: 90

# %% [markdown]
# # ASSIGNMENT 6. Create a tuple of subjects

# %%
subjects = ("Math", "English", "Science")
print(subjects)
print(subjects[0])
# Out:
# ('Math', 'English', 'Science')
# Math

# %% [markdown]
# # ASSIGNMENT 7. Create a set of unique scores

# %%
scores_set = {80,30,50,45,75}
print(scores_set)
# Out:
# {80, 50, 75, 45, 30}

# %% [markdown]
# Name Friday Ritmwa Hope
# Course DTS
# Department Data science
# Faculty computing
# Matric number UJ/2025/cp/0416

# %% [markdown]
# Good Job!
